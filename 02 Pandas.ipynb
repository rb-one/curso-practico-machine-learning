# %%
import pandas as pd

# %% [markdown]
# ## Series

# %%
series = pd.Series([5,10,15,20,25])

# %%
series
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
series[3]
# Out:
# 20

# %%
cad = pd.Series(['p','l','a','t','z','i'])

# %%
cad
# Out:
# 0    p
# 1    l
# 2    a
# 3    t
# 4    z
# 5    i
# dtype: object

# %% [markdown]
# ## DataFrames

# %%
lista = ['Hola', 'Mundo', 'Robotico']
df = pd.DataFrame(lista)

# %%
df
# Out:
#           0
# 0      Hola
# 1     Mundo
# 2  Robotico

# %%
data = {'Nombre': ['Juan', 'Ana', 'Jose', 'Arturo'],
        'edad': [25, 18, 23, 27],
        'pais': ['MEX', 'COL', 'USA', 'BRA']
        }

df = pd.DataFrame(data)
df
# Out:
#    Nombre  edad pais
# 0    Juan    25  MEX
# 1     Ana    18  COL
# 2    Jose    23  USA
# 3  Arturo    27  BRA

# %%
df[['Nombre', 'edad']]
# Out:
#    Nombre  edad
# 0    Juan    25
# 1     Ana    18
# 2    Jose    23
# 3  Arturo    27

# %% [markdown]
# ## Leer archivos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Curso practico machine learning
# Out:
# /content/drive/MyDrive/Colab Notebooks/Curso practico machine learning

# %%
# %ls
# Out:
# '01 numpy.ipynb'   canciones-2018.csv   Pandas.ipynb   salarios.csv

# %%
data = pd.read_csv('canciones-2018.csv')
data.head()
# Out:
#                       id  ... time_signature
# 0  6DCZcSspjsKoFjzjrWoCd  ...            4.0
# 1  3ee8Jmje8o58CHK66QrVC  ...            4.0
# 2  0e7ipj03S05BNilyu5bRz  ...            4.0
# 3  3swc6WTsr7rl9DqQKQA55  ...            4.0
# 4  2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
#
# [5 rows x 16 columns]

# %%
artista = data.artists
artista[5]
# Out:
# 'Post Malone'

# %%
info = data.iloc[15]
info
# Out:
# id                     3GCdLUSnKSMJhs4Tj6CV3
# name                All The Stars (with SZA)
# artists                       Kendrick Lamar
# danceability                           0.698
# energy                                 0.633
# key                                        8
# loudness                              -4.946
# mode                                       1
# speechiness                           0.0597
# acousticness                          0.0605
# instrumentalness                    0.000194
# liveness                              0.0926
# valence                                0.552
# tempo                                 96.924
# duration_ms                           232187
# time_signature                             4
# Name: 15, dtype: object

# %%
data.loc[15].id
# Out:
# '3GCdLUSnKSMJhs4Tj6CV3'

# %%
# Final de dataframe
data.tail()
# Out:
#                        id  ... time_signature
# 95  630sXRhIcfwr2e4RdNtjK  ...            4.0
# 96  2xmrfQpmS2iJExTlklLoA  ...            4.0
# 97  5WvAo7DNuPRmk4APhdPzi  ...            5.0
# 98  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
# 99  3EPXxR3ImUwfayaurPi3c  ...            4.0
#
# [5 rows x 16 columns]

# %%
# Tamaño del DataFrame
data.shape
# Out:
# (100, 16)

# %%
data.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
# Describir tipos de variables del DataFrame
data['tempo'].describe()
# Out:
# count    100.000000
# mean     119.904180
# std       28.795984
# min       64.934000
# 25%       95.730750
# 50%      120.116000
# 75%      140.022750
# max      198.075000
# Name: tempo, dtype: float64

# %%
# Ordenar datframe por su index
data.sort_index(axis=0, ascending=False)
# Out:
#                        id  ... time_signature
# 99  3EPXxR3ImUwfayaurPi3c  ...            4.0
# 98  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
# 97  5WvAo7DNuPRmk4APhdPzi  ...            5.0
# 96  2xmrfQpmS2iJExTlklLoA  ...            4.0
# 95  630sXRhIcfwr2e4RdNtjK  ...            4.0
# ..                    ...  ...            ...
# 4   2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
# 3   3swc6WTsr7rl9DqQKQA55  ...            4.0
# 2   0e7ipj03S05BNilyu5bRz  ...            4.0
# 1   3ee8Jmje8o58CHK66QrVC  ...            4.0
# 0   6DCZcSspjsKoFjzjrWoCd  ...            4.0
#
# [100 rows x 16 columns]

# %%
# reto Seleccionar 3 columnas y ordenarlas de manera ascendente
sub_df = data[['name', 'artists', 'danceability']]
sub_df
# Out:
#                                  name       artists  danceability
# 0                          God's Plan         Drake         0.754
# 1                                SAD!  XXXTENTACION         0.740
# 2          rockstar (feat. 21 Savage)   Post Malone         0.587
# 3        Psycho (feat. Ty Dolla $ign)   Post Malone         0.739
# 4                      In My Feelings         Drake         0.835
# ..                                ...           ...           ...
# 95                  Rewrite The Stars     Zac Efron         0.684
# 96  I Miss You (feat. Julia Michaels)  Clean Bandit         0.638
# 97                         No Brainer     DJ Khaled         0.552
# 98        Dusk Till Dawn - Radio Edit          ZAYN         0.258
# 99                         Be Alright    Dean Lewis         0.553
#
# [100 rows x 3 columns]

# %%
sub_df.sort_values(by='danceability',axis=0, ascending=True)
# Out:
#                                       name        artists  danceability
# 98             Dusk Till Dawn - Radio Edit           ZAYN         0.258
# 93                              This Is Me   Keala Settle         0.284
# 80                    lovely (with Khalid)  Billie Eilish         0.351
# 49                        Call Out My Name     The Weeknd         0.489
# 11                            Lucid Dreams     Juice WRLD         0.511
# ..                                     ...            ...           ...
# 61                                 Nonstop          Drake         0.912
# 18                               Moonlight   XXXTENTACION         0.921
# 19                Look Alive (feat. Drake)     BlocBoy JB         0.922
# 55  FEFE (feat. Nicki Minaj & Murda Beatz)        6ix9ine         0.931
# 91                              Yes Indeed       Lil Baby         0.964
#
# [100 rows x 3 columns]

# %%
data.head()
# Out:
#                       id  ... time_signature
# 0  6DCZcSspjsKoFjzjrWoCd  ...            4.0
# 1  3ee8Jmje8o58CHK66QrVC  ...            4.0
# 2  0e7ipj03S05BNilyu5bRz  ...            4.0
# 3  3swc6WTsr7rl9DqQKQA55  ...            4.0
# 4  2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
#
# [5 rows x 16 columns]
